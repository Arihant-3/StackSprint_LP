# %% [markdown]
# # ⬇️ **Day 17: GitHub API + Streamlit Developer Dashboard**

# %% [markdown]
# Build a dashboard using the GitHub API to analyze your own (or any user’s) profile — repositories, stars, forks, languages, and more.

# %% [markdown]
# ---

# %% [markdown]
# - Access GitHub data using the **GitHub REST API**
# - Authenticate with a **Personal Access Token (PAT)** for private or high-rate access
# - Visualize repositories, languages, stars, etc.
# - Create a simple Streamlit dashboard

# %% [markdown]
# ---

# %% [markdown]
# ## 🔐 Get a GitHub Personal Access Token (PAT)
#
# 1. Go to [GitHub → Settings → Developer Settings → Personal Access Tokens](https://github.com/settings/tokens)
# 2. Click **“Fine-grained tokens”**
# 3. Select repo, read-only scope
# 4. Copy your token and **store it securely** (use `.env` or `st.secrets`)

# %% [markdown]
# Testing -

# %%
import requests 
import json
import os 
from dotenv import load_dotenv
load_dotenv()

username = 'Arihant-3'
GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')

headers = {
    "Authorization": f"Bearer {GITHUB_TOKEN}",
    "Accept": "application/vnd.github+json"
}

url = f"https://api.github.com/users/{username}"
response = requests.get(url, headers=headers)

data = response.json()
print(data)
print(type(data))
str_data = json.dumps(data, indent=4)
print(str_data)
print(type(str_data))

print("Status Code : ", response.status_code)
# Out:
# {'login': 'Arihant-3', 'id': 185806094, 'node_id': 'U_kgDOCxMtDg', 'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Arihant-3', 'html_url': 'https://github.com/Arihant-3', 'followers_url': 'https://api.github.com/users/Arihant-3/followers', 'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}', 'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions', 'organizations_url': 'https://api.github.com/users/Arihant-3/orgs', 'repos_url': 'https://api.github.com/users/Arihant-3/repos', 'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Arihant-3/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'name': 'Aryan Burnwal', 'company': None, 'blog': '', 'location': 'India', 'email': 'aburnwal26@gmail.com', 'hireable': None, 'bio': 'AI/ML enthusiast exploring real-world problems with data-driven solutions and a learner’s mindset.', 'twitter_username': None, 'public_repos': 7, 'public_gists': 0, 'followers': 0, 'following': 1, 'created_at': '2024-10-21T13:24:42Z', 'updated_at': '2025-07-04T21:26:28Z'}
# <class 'dict'>
# {
#     "login": "Arihant-3",
#     "id": 185806094,
#     "node_id": "U_kgDOCxMtDg",
#     "avatar_url": "https://avatars.githubusercontent.com/u/185806094?v=4",
#     "gravatar_id": "",
#     "url": "https://api.github.com/users/Arihant-3",
#     "html_url": "https://github.com/Arihant-3",
#     "followers_url": "https://api.github.com/users/Arihant-3/followers",
#     "following_url": "https://api.github.com/users/Arihant-3/following{/other_user}",
#     "gists_url": "https://api.github.com/users/Arihant-3/gists{/gist_id}",
#     "starred_url": "https://api.github.com/users/Arihant-3/starred{/owner}{/repo}",
#     "subscriptions_url": "https://api.github.com/users/Arihant-3/subscriptions",
#     "organizations_url": "https://api.github.com/users/Arihant-3/orgs",
#     "repos_url": "https://api.github.com/users/Arihant-3/repos",
#     "events_url": "https://api.github.com/users/Arihant-3/events{/privacy}",
#     "received_events_url": "https://api.github.com/users/Arihant-3/received_events",
#     "type": "User",
#     "user_view_type": "public",
#     "site_admin": false,
#     "name": "Aryan Burnwal",
#     "company": null,
#     "blog": "",
#     "location": "India",
#     "email": "aburnwal26@gmail.com",
#     "hireable": null,
#     "bio": "AI/ML enthusiast exploring real-world problems with data-driven solutions and a learner\u2019s mindset.",
#     "twitter_username": null,
#     "public_repos": 7,
#     "public_gists": 0,
#     "followers": 0,
#     "following": 1,
#     "created_at": "2024-10-21T13:24:42Z",
#     "updated_at": "2025-07-04T21:26:28Z"
# }
# <class 'str'>
# Status Code :  200

# %%
response.headers
# Out:
# {'Date': 'Tue, 05 Aug 2025 11:53:29 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'private, max-age=60, s-maxage=60', 'Vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"7f1892773dac96d86335d4fdf16ff2b2807ef66794940f3c217c1a13aa03e191"', 'Last-Modified': 'Fri, 04 Jul 2025 21:26:28 GMT', 'github-authentication-token-expiration': '2025-09-04 16:45:33 +0530', 'X-GitHub-Media-Type': 'github.v3; format=json', 'x-github-api-version-selected': '2022-11-28', 'X-RateLimit-Limit': '5000', 'X-RateLimit-Remaining': '4959', 'X-RateLimit-Reset': '1754395167', 'X-RateLimit-Used': '41', 'X-RateLimit-Resource': 'core', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Server': 'github.com', 'X-GitHub-Request-Id': 'FDF0:2C31A7:82E5E1:96C6EC:6891F0B9'}

# %%
print(data['name'])
print(data['location'])
print(data['public_repos'])
print(data['following'])
print(data['followers'])
# Out:
# Aryan Burnwal
# India
# 7
# 1
# 0
# https://api.github.com/users/Arihant-3/followers

# %%
repo_url = f"https://api.github.com/users/{username}/repos?per_page=100"
repo_resp = requests.get(repo_url, headers=headers)
repo_data = repo_resp.json()

print(repo_resp.status_code)

repo_data
# Out:
# 200
# [{'id': 1001466820,
#   'node_id': 'R_kgDOO7ErxA',
#   'name': 'Analyst-Forge',
#   'full_name': 'Arihant-3/Analyst-Forge',
#   'private': False,
#   'owner': {'login': 'Arihant-3',
#    'id': 185806094,
#    'node_id': 'U_kgDOCxMtDg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arihant-3',
#    'html_url': 'https://github.com/Arihant-3',
#    'followers_url': 'https://api.github.com/users/Arihant-3/followers',
#    'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arihant-3/orgs',
#    'repos_url': 'https://api.github.com/users/Arihant-3/repos',
#    'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arihant-3/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arihant-3/Analyst-Forge',
#   'description': 'A self-driven 30-day challenge to master data reading and insight generation using Python and Power BI.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge',
#   'forks_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/forks',
#   'keys_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/teams',
#   'hooks_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/events',
#   'assignees_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/tags',
#   'blobs_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/subscription',
#   'commits_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/merges',
#   'archive_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/downloads',
#   'issues_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arihant-3/Analyst-Forge/deployments',
#   'created_at': '2025-06-13T12:34:26Z',
#   'updated_at': '2025-08-01T08:31:17Z',
#   'pushed_at': '2025-07-13T23:07:34Z',
#   'git_url': 'git://github.com/Arihant-3/Analyst-Forge.git',
#   'ssh_url': 'git@github.com:Arihant-3/Analyst-Forge.git',
#   'clone_url': 'https://github.com/Arihant-3/Analyst-Forge.git',
#   'svn_url': 'https://github.com/Arihant-3/Analyst-Forge',
#   'homepage': None,
#   'size': 4492,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 1001875510,
#   'node_id': 'R_kgDOO7doNg',
#   'name': 'Arihant-3',
#   'full_name': 'Arihant-3/Arihant-3',
#   'private': False,
#   'owner': {'login': 'Arihant-3',
#    'id': 185806094,
#    'node_id': 'U_kgDOCxMtDg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arihant-3',
#    'html_url': 'https://github.com/Arihant-3',
#    'followers_url': 'https://api.github.com/users/Arihant-3/followers',
#    'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arihant-3/orgs',
#    'repos_url': 'https://api.github.com/users/Arihant-3/repos',
#    'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arihant-3/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arihant-3/Arihant-3',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arihant-3/Arihant-3',
#   'forks_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/forks',
#   'keys_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/teams',
#   'hooks_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/events',
#   'assignees_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/tags',
#   'blobs_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/subscription',
#   'commits_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/merges',
#   'archive_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/downloads',
#   'issues_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arihant-3/Arihant-3/deployments',
#   'created_at': '2025-06-14T08:11:08Z',
#   'updated_at': '2025-06-14T08:21:11Z',
#   'pushed_at': '2025-06-14T08:21:08Z',
#   'git_url': 'git://github.com/Arihant-3/Arihant-3.git',
#   'ssh_url': 'git@github.com:Arihant-3/Arihant-3.git',
#   'clone_url': 'https://github.com/Arihant-3/Arihant-3.git',
#   'svn_url': 'https://github.com/Arihant-3/Arihant-3',
#   'homepage': None,
#   'size': 7,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 1025063014,
#   'node_id': 'R_kgDOPRk4Zg',
#   'name': 'AutoGraphix',
#   'full_name': 'Arihant-3/AutoGraphix',
#   'private': False,
#   'owner': {'login': 'Arihant-3',
#    'id': 185806094,
#    'node_id': 'U_kgDOCxMtDg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arihant-3',
#    'html_url': 'https://github.com/Arihant-3',
#    'followers_url': 'https://api.github.com/users/Arihant-3/followers',
#    'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arihant-3/orgs',
#    'repos_url': 'https://api.github.com/users/Arihant-3/repos',
#    'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arihant-3/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arihant-3/AutoGraphix',
#   'description': 'AutoGraphix is a smart Streamlit app that lets you clean, explore, and visualize any CSV dataset — all with guided choices and one click. Upload, fix nulls, encode, and auto-generate beautiful graphs.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arihant-3/AutoGraphix',
#   'forks_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/forks',
#   'keys_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/teams',
#   'hooks_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/events',
#   'assignees_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/tags',
#   'blobs_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/subscription',
#   'commits_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/merges',
#   'archive_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/downloads',
#   'issues_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arihant-3/AutoGraphix/deployments',
#   'created_at': '2025-07-23T16:58:42Z',
#   'updated_at': '2025-07-24T15:31:32Z',
#   'pushed_at': '2025-07-24T12:45:39Z',
#   'git_url': 'git://github.com/Arihant-3/AutoGraphix.git',
#   'ssh_url': 'git@github.com:Arihant-3/AutoGraphix.git',
#   'clone_url': 'https://github.com/Arihant-3/AutoGraphix.git',
#   'svn_url': 'https://github.com/Arihant-3/AutoGraphix',
#   'homepage': 'https://autographix.streamlit.app',
#   'size': 23,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 1029796057,
#   'node_id': 'R_kgDOPWFw2Q',
#   'name': 'Layoffs-Analysis',
#   'full_name': 'Arihant-3/Layoffs-Analysis',
#   'private': False,
#   'owner': {'login': 'Arihant-3',
#    'id': 185806094,
#    'node_id': 'U_kgDOCxMtDg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arihant-3',
#    'html_url': 'https://github.com/Arihant-3',
#    'followers_url': 'https://api.github.com/users/Arihant-3/followers',
#    'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arihant-3/orgs',
#    'repos_url': 'https://api.github.com/users/Arihant-3/repos',
#    'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arihant-3/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arihant-3/Layoffs-Analysis',
#   'description': 'Layoffs dataset project | SQL data cleaning, EDA, and Power BI dashboard | Kaggle data analysis (2020–2025)',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis',
#   'forks_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/forks',
#   'keys_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/teams',
#   'hooks_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/events',
#   'assignees_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/tags',
#   'blobs_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/subscription',
#   'commits_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/merges',
#   'archive_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/downloads',
#   'issues_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arihant-3/Layoffs-Analysis/deployments',
#   'created_at': '2025-07-31T15:30:02Z',
#   'updated_at': '2025-08-01T21:15:45Z',
#   'pushed_at': '2025-08-01T21:15:42Z',
#   'git_url': 'git://github.com/Arihant-3/Layoffs-Analysis.git',
#   'ssh_url': 'git@github.com:Arihant-3/Layoffs-Analysis.git',
#   'clone_url': 'https://github.com/Arihant-3/Layoffs-Analysis.git',
#   'svn_url': 'https://github.com/Arihant-3/Layoffs-Analysis',
#   'homepage': None,
#   'size': 706,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 997804628,
#   'node_id': 'R_kgDOO3lKVA',
#   'name': 'ML_Test_Project',
#   'full_name': 'Arihant-3/ML_Test_Project',
#   'private': False,
#   'owner': {'login': 'Arihant-3',
#    'id': 185806094,
#    'node_id': 'U_kgDOCxMtDg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arihant-3',
#    'html_url': 'https://github.com/Arihant-3',
#    'followers_url': 'https://api.github.com/users/Arihant-3/followers',
#    'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arihant-3/orgs',
#    'repos_url': 'https://api.github.com/users/Arihant-3/repos',
#    'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arihant-3/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arihant-3/ML_Test_Project',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project',
#   'forks_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/forks',
#   'keys_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/teams',
#   'hooks_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/events',
#   'assignees_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/tags',
#   'blobs_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/subscription',
#   'commits_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/merges',
#   'archive_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/downloads',
#   'issues_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arihant-3/ML_Test_Project/deployments',
#   'created_at': '2025-06-07T08:08:56Z',
#   'updated_at': '2025-06-17T10:18:52Z',
#   'pushed_at': '2025-06-17T10:18:48Z',
#   'git_url': 'git://github.com/Arihant-3/ML_Test_Project.git',
#   'ssh_url': 'git@github.com:Arihant-3/ML_Test_Project.git',
#   'clone_url': 'https://github.com/Arihant-3/ML_Test_Project.git',
#   'svn_url': 'https://github.com/Arihant-3/ML_Test_Project',
#   'homepage': None,
#   'size': 1749,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 878112528,
#   'node_id': 'R_kgDONFbvEA',
#   'name': 'Movie-Data-Analysis',
#   'full_name': 'Arihant-3/Movie-Data-Analysis',
#   'private': False,
#   'owner': {'login': 'Arihant-3',
#    'id': 185806094,
#    'node_id': 'U_kgDOCxMtDg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arihant-3',
#    'html_url': 'https://github.com/Arihant-3',
#    'followers_url': 'https://api.github.com/users/Arihant-3/followers',
#    'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arihant-3/orgs',
#    'repos_url': 'https://api.github.com/users/Arihant-3/repos',
#    'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arihant-3/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arihant-3/Movie-Data-Analysis',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis',
#   'forks_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/forks',
#   'keys_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/teams',
#   'hooks_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/events',
#   'assignees_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/tags',
#   'blobs_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/subscription',
#   'commits_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/merges',
#   'archive_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/downloads',
#   'issues_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arihant-3/Movie-Data-Analysis/deployments',
#   'created_at': '2024-10-24T19:56:12Z',
#   'updated_at': '2024-10-24T21:33:30Z',
#   'pushed_at': '2024-10-24T21:33:26Z',
#   'git_url': 'git://github.com/Arihant-3/Movie-Data-Analysis.git',
#   'ssh_url': 'git@github.com:Arihant-3/Movie-Data-Analysis.git',
#   'clone_url': 'https://github.com/Arihant-3/Movie-Data-Analysis.git',
#   'svn_url': 'https://github.com/Arihant-3/Movie-Data-Analysis',
#   'homepage': None,
#   'size': 174,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 998983482,
#   'node_id': 'R_kgDOO4tHOg',
#   'name': 'TheThinkingPath',
#   'full_name': 'Arihant-3/TheThinkingPath',
#   'private': False,
#   'owner': {'login': 'Arihant-3',
#    'id': 185806094,
#    'node_id': 'U_kgDOCxMtDg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/185806094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arihant-3',
#    'html_url': 'https://github.com/Arihant-3',
#    'followers_url': 'https://api.github.com/users/Arihant-3/followers',
#    'following_url': 'https://api.github.com/users/Arihant-3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Arihant-3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Arihant-3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Arihant-3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Arihant-3/orgs',
#    'repos_url': 'https://api.github.com/users/Arihant-3/repos',
#    'events_url': 'https://api.github.com/users/Arihant-3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Arihant-3/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Arihant-3/TheThinkingPath',
#   'description': 'A logic-first problem solving project — 30 challenges framed in LaTeX, guided by ChatGPT.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath',
#   'forks_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/forks',
#   'keys_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/teams',
#   'hooks_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/events',
#   'assignees_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/tags',
#   'blobs_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/languages',
#   'stargazers_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/subscription',
#   'commits_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/merges',
#   'archive_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/downloads',
#   'issues_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Arihant-3/TheThinkingPath/deployments',
#   'created_at': '2025-06-09T14:59:47Z',
#   'updated_at': '2025-06-09T15:19:25Z',
#   'pushed_at': '2025-06-09T15:19:16Z',
#   'git_url': 'git://github.com/Arihant-3/TheThinkingPath.git',
#   'ssh_url': 'git@github.com:Arihant-3/TheThinkingPath.git',
#   'clone_url': 'https://github.com/Arihant-3/TheThinkingPath.git',
#   'svn_url': 'https://github.com/Arihant-3/TheThinkingPath',
#   'homepage': None,
#   'size': 820,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'TeX',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}}]

# %%
all_repo = []

for repo in repo_data:
        all_repo.append(repo['name'])
print(all_repo)
# Out:
# ['Analyst-Forge', 'Arihant-3', 'AutoGraphix', 'Layoffs-Analysis', 'ML_Test_Project', 'Movie-Data-Analysis', 'TheThinkingPath']
